# %%
import tensorflow
tensorflow.__version__
# Out:
# '2.3.1'

# %% [markdown]
# # Text generation with LSTM
#
# This notebook contains the code samples found in Chapter 8, Section 1 of [Deep Learning with Python](https://www.manning.com/books/deep-learning-with-python?a_aid=keras&a_bid=76564dff). Note that the original text features far more content, in particular further explanations and figures: in this notebook, you will only find source code and related comments.
#
# ----
#
# [...]
#
# ## Implementing character-level LSTM text generation
#
#
# Let's put these ideas in practice in a Keras implementation. The first thing we need is a lot of text data that we can use to learn a
# language model. You could use any sufficiently large text file or set of text files -- Wikipedia, the Lord of the Rings, etc. In this
# example we will use some of the writings of Nietzsche, the late-19th century German philosopher (translated to English). The language model
# we will learn will thus be specifically a model of Nietzsche's writing style and topics of choice, rather than a more generic model of the
# English language.

# %% [markdown]
# ## Preparing the data
#
# Let's start by downloading the corpus and converting it to lowercase:

# %%
import numpy as np

path = tensorflow.keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('Corpus length:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# Corpus length: 600893

# %% [markdown]
# Next, we will extract partially-overlapping sequences of length `maxlen`, one-hot encode them and pack them in a 3D Numpy array `x` of
# shape `(sequences, maxlen, unique_characters)`. Simultaneously, we prepare a array `y` containing the corresponding targets: the one-hot
# encoded characters that come right after each extracted sequence.

# %%
# Length of extracted character sequences
maxlen = 60

# We sample a new sequence every `step` characters
step = 3

# This holds our extracted sequences
sentences = []

# This holds the targets (the follow-up characters)
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('Number of sequences:', len(sentences))

# List of unique characters in the corpus
chars = sorted(list(set(text)))
print('Unique characters:', len(chars))
# Dictionary mapping unique characters to their index in `chars`
char_indices = dict((char, chars.index(char)) for char in chars)

# Next, one-hot encode the characters into binary arrays.
print('Vectorization...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# Number of sequences: 200278
# Unique characters: 57
# Vectorization...

# %% [markdown]
# ## Building the network
#
# Our network is a single `LSTM` layer followed by a `Dense` classifier and softmax over all possible characters. But let us note that
# recurrent neural networks are not the only way to do sequence data generation; 1D convnets also have proven extremely successful at it in
# recent times.

# %%
from tensorflow.keras import layers

model = tensorflow.keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# Since our targets are one-hot encoded, we will use `categorical_crossentropy` as the loss to train the model:

# %%
optimizer = tensorflow.keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## Training the language model and sampling from it
#
#
# Given a trained model and a seed text snippet, we generate new text by repeatedly:
#
# * 1) Drawing from the model a probability distribution over the next character given the text available so far
# * 2) Reweighting the distribution to a certain "temperature"
# * 3) Sampling the next character at random according to the reweighted distribution
# * 4) Adding the new character at the end of the available text
#
# This is the code we use to reweight the original probability distribution coming out of the model,
# and draw a character index from it (the "sampling function"):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# Finally, this is the loop where we repeatedly train and generated text. We start generating text using a range of different temperatures
# after every epoch. This allows us to see how the generated text evolves as the model starts converging, as well as the impact of
# temperature in the sampling strategy.

# %%
import random
import sys

for epoch in range(1, 60):
    print('epoch', epoch)
    # Fit the model for 1 epoch on the available training data
    model.fit(x, y,
              batch_size=128,
              epochs=1)

    # Select a text seed at random
    start_index = random.randint(0, len(text) - maxlen - 1)
    generated_text = text[start_index: start_index + maxlen]
    print('--- Generating with seed: "' + generated_text + '"')

    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ temperature:', temperature)
        sys.stdout.write(generated_text)

        # We generate 400 characters
        for i in range(400):
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# epoch 1
# 1565/1565 [==============================] - 75s 48ms/step - loss: 1.9645
# --- Generating with seed: "ally, to
# heal our ills, or strive and trouble ourselves to g"
# ------ temperature: 0.2
# ally, to
# heal our ills, or strive and trouble ourselves to genis and the presention of the consequent of the selved the more of the something of the servented the selved and an in the science of the same and more of the consequently of the something and the man the something of the something of the something and the something and an and moral and an and entires and of the something the consequent to the science of the something and the consequent to the st
# ------ temperature: 0.5
# to the science of the something and the consequent to the strong but to the lived to the complects, and as such of the opposelty and the one the something of the
# present of the something of the science, the precences and on the such and judgity of allost an antathy of the spirits of the sense in the present do well prose of willing of to a nother an in an inconselved of the conscience of way now are the enribulled than any is it of the ounsaristing of the
# ------ temperature: 1.0
# re the enribulled than any is it of the ounsaristing of the elived that in whiecertrairer whene existent loves of a there evening his wancounts the daped--whinher be not with
# "fore them willed, whather phenoms i have daitton beforess un so the have the man of that refigio,
# an and of consended, of detanes of love one costish.
#
#
#
# 1
#
#
#
#
#
#
# =cop
#
# "crat, now
# of even noch eumore, from in docanced, the wholong--again a wayss when
# the pelies of cmarims thinksy," wh
# ------ temperature: 1.2
# olong--again a wayss when
# the pelies of cmarims thinksy," whichit, shorifinzled un, an also pquioritytans, custach 's execkty one ecevanivatus of
# themenctisble
# must begreabfle and woncenees
#  satfirquation nastances, were philoquestuonat; aowgonely and alwed" than in neventen, ons! only, be wow in kind, an in ewhict
# has, and barfiotad (shabt?
# or its excemsticm"--entingquil
# ansacity. pnecoss in reevt to which is begny, edradudy, and ik. have
# even allo. an th
# epoch 2
# 1565/1565 [==============================] - 88s 57ms/step - loss: 1.6159
# --- Generating with seed: ", stupefy, amaze, bedazzle. there is but one thing
# that it d"
# ------ temperature: 0.2
# , stupefy, amaze, bedazzle. there is but one thing
# that it deep and and a something of the presentally and the more as the and the perhaps and something the sense of the servent of the servent of the sense of the sense in the and interpersent the presentarily and the proved and the and the sense of the sense of the one of the something and the presentard and the every and the presentard and the and as the be a something and a such as a doubling and as a se
# ------ temperature: 0.5
# d as the be a something and a such as a doubling and as a secret of a longer to the obiduality and the therefore the power the pound and and a have is that the how a been the as a pertain and perhaps and of the sense of the feels that is for the not compresies and the one of all the truth and interperation of the expressed to despociation one wis a scove and as in the and interead and arto man has callves and something which is a part and proverstone to he
# ------ temperature: 1.0
#  callves and something which is a part and proverstone to he ware as shar
# int! perhaps fro spirit and
# howe, and with is. the poss; frughtesation, iugutesmanians and peal lansinting-but
# for fexpeadation that it this ward sover mankind sympathology the uist, heils how comisinual, in moble wonouf, thrible for ifeconsceadite of linderes and the
# shoulds that the is one out of lems mereled and lessed metapxicicilating
# to should not this have boty. the noo reason
# ------ temperature: 1.2
# tapxicicilating
# to should not this have boty. the noo reasonenwal, but inteilows.
#
# ee. to posseuritiam and sway cundiminly clise as thmole steremal crouse part"; also is almost arenxally moriading thringulelushy and
# philosophing able, in chat, amsinic ringwity" af
# activemans for in
# the locist?, attuslest is noy to quiblation, it confonbed to langer ill
# painfed socatorm to cunisexitariage or feech. and not" comasushquanly infless the
# tappises
# as joutble pre
# epoch 3
# 1565/1565 [==============================] - 92s 59ms/step - loss: 1.5283
# --- Generating with seed: " one another wholly.
#
#
# 76
#
# =the ascetic.=--the ascetic makes"
# ------ temperature: 0.2
#  one another wholly.
#
#
# 76
#
# =the ascetic.=--the ascetic makes in the man of the present, the same the self-man of the philosophers and the as the present the present, and the presented the presented and the present, and the present the presented the present the present the general and an interpretation of the philosophers of the philosophy and the as the betient the same and the present and the higher the self-man of the self-surposision and the present the
# ------ temperature: 0.5
# her the self-man of the self-surposision and the present the presting the constraint from a hard into himself, and the reason of the last man the greater of the ground which he have been dest and the
# appresisly explanably the most every which is the designated of the reason the far the servant the chare
# imposition, the benement and presumption on the concerning the senses of the short and sulper to the world, one which as the persons and there of
# the super
# ------ temperature: 1.0
# o the world, one which as the persons and there of
# the super. happendening to causously, the side every shels to the philosophy to as philosopher; our the phristians what, the indignioned
# things--what pethreal beal by fasulners of things
# divine
# withire as ax its labstrain preas
# hat the holegord amplesination, which troundly,
# the
# templetious", some and lover surped well the unctually the gree-when
# forlumparistord. there servicuful  have grake explanation
# th
# ------ temperature: 1.2
# forlumparistord. there servicuful  have grake explanation
# the messory of
# sapidoaaral al; they how nether, doubl; are might all himselca heart trestimation at yety!
#
#
# eccappuartiving tran schatye:--as to
# ourselves theoeirabas regard with king.
#
#
# la
# cabontered lifenl, the world who nam! fum 3hts the othrouss what grares
# religion instrumness arishes to the "digrent,minaar is
# the cholation and far
# id thousa ocer by deachment apprications that the petters and r
# epoch 4
# 1565/1565 [==============================] - 90s 57ms/step - loss: 1.4804
# --- Generating with seed: "all something complicated, something that is a unity only in"
# ------ temperature: 0.2
# all something complicated, something that is a unity only in the souls of the same the same in the same the precisely the same the conscious of the such an exception of the same of the same and strength and the such an ancient will be the sense of the same and should and the same the same the sacrificed to the conscious and spirituality of the conscious conscious and souls and the man of the conscious conscious and the same one and strength of the consciou
# ------ temperature: 0.5
# ious conscious and the same one and strength of the conscious, in the convaction of the conscious the virtue of conscious false of the spirit far the world and been and man be the senseful the same refined and entire to the hand to the freedom in the same the conscious dectuately to the sense of the sensation of the conscious and men that the personal in such a sould and fundamentally of the the extropes, the such the world to the such an the conscience, a
# ------ temperature: 1.0
# xtropes, the such the world to the such an the conscience, as indifferent b, a smole one precisely man hik only enrighthed to his heart, towards the
# breeps and succimil. whereis est k and applachestness, manifications even their all of them, what-vequally mensication of duding eghilowing of "under skain of place, he own consequently
# how attain and senmection, whoily are preciatly it lood," menation in
# itsualled with hands--is lokely," and every strength im
# ------ temperature: 1.2
# n in
# itsualled with hands--is lokely," and every strength imsentes nringlikened it is in all sucalityest to what de  also nature prefear
# spibilitied than bgous ay look saie thousanci that, of the freed can be let its moral as  wherethern horsess  or de.
# -hicher
# own
# aga now prescience which
# as asmord bything-whoed heavepentarble. to emousient virtus, man, wh thingful? cond
# that they sonliving y, of the
# brecosppaned than "begin met, whatert themselves he
# ca
# epoch 5
# 1565/1565 [==============================] - 93s 59ms/step - loss: 1.4520
# --- Generating with seed: "ers, presumptuous
# pitiful bunglers, what have you done! was "
# ------ temperature: 0.2
# ers, presumptuous
# pitiful bunglers, what have you done! was the contemplanic of the same the more the man of the sense of the man of the sense of the same and the more the subtle for and distingual with the delicate and the world to the same and the spirit the man of the same the spiritual the sound of the same and the sense of the world and the soul of the more the same and more who has a deal and the standard of the same and the present to the world to t
# ------ temperature: 0.5
# d the standard of the same and the present to the world to the farance of the moralist and good of the reasher for even world and
# all the believe with fact of many consequent sopething the moralists, and more for the mind and the proviction to false and for the distrust and forms of the one may as the consequent something against according to long the man of the man of the
# contraction and then it is sentiment to our lows, which has something the asmection
# ------ temperature: 1.0
# is sentiment to our lows, which has something the asmection suopicar musppely thas to wonly respon in so that they will like there i ratimate, and thoughtable which must s that it at the civilization, the "knows, in more and bother and say (                     with man, which
# degakely from monsical human rades he operard"
# jused to the science to the embe of fearranges themselves stoot intivects in
# such all all will man
# to be responsibility, an the nead fr
# ------ temperature: 1.2
# n
# such all all will man
# to be responsibility, an the nead frownesd,
# ourahet-ming. on him hand grounded
# must
# favoteancy of exampxgyogely that
# every
# more (the pre own) dundliutty pecharing,ing toknonismly,
# dived. as"
# the
# pvach, they sabrdentes, more reesimenne conligh, a bruins! i experial "futholem un:
#                for the appearing)
# with contathed- placed pholoses was generace,
# and
# be." oo scarally inflyence to been primition th the sedver (or in mentin
# epoch 6
# 1565/1565 [==============================] - 91s 58ms/step - loss: 1.4290
# --- Generating with seed: "as of virtue.=--every virtue has its privilege: for
# example,"
# ------ temperature: 0.2
# as of virtue.=--every virtue has its privilege: for
# example, the spiritual the soul--that the soul of the soul of the soul of the spirits of the soul--that the sense of the solution of the same the stand of the strongest that the soul--that the soul of the soul--that the soul of the soul--the stand and the soul-such a conserved that the soul of the soul--the same the soul-stands its extrame and the sense of the soul of the spirits to the sense of the soul-
# ------ temperature: 0.5
# e sense of the soul of the spirits to the sense of the soul-soul of the ordists and the great that the man sucharing the present, that the soul-suof the most consent of determine of the conduct of the does not soul, it is one is an animals (and soris will a new conservation of the piles, is the thing that the religion to have this species of the soul, what is allow that the belief, society of the free spirits, and the the sense of the semplessifical sacrif
# ------ temperature: 1.0
# free spirits, and the the sense of the semplessifical sacrifice of
# ending, judt as
# something, with its bould,
# away
# impurriges unt" keer of hard
# in co, his
# gexed rageged, has them that "fors: those plunged it , in shall it
# our has, it is themselves that it is inot
# acfoar, what to was
# power prowed acts  of nai, precisely growther, accordingly desth to characiency of the knowide,
# that or them for boot origial the well, that those barnes
# what delichty, and its
# ------ temperature: 1.2
# t origial the well, that those barnes
# what delichty, and its furm-still--intaking,
# mowing dod being   of decansed "inflo-ingsections, it
# he stands hondoped.
#
#
# o
#
#
# 1xcision, stand; that the coont, develous, "evolution how not youly, or ; stall
# be  ye all--they wiss law expression
# what is geartion with all the sense as tays easily-beightid, thus-plant aw. ie resistons men that it evyrank and whar cruelty, do, our aptasion of
# zind within aris a(quirecoutd
# sti
# epoch 7
# 1565/1565 [==============================] - 90s 57ms/step - loss: 1.4121
# --- Generating with seed: "in a mighty unity, which afterwards
# branches off and develop"
# ------ temperature: 0.2
# in a mighty unity, which afterwards
# branches off and developed to the spirit of the sure and desires of the indistingul, and the successing the world and all the same the does not be all the desire and world and fore and the spirit, and in the same an art of the comparison, the present and the present of the sure and successing of the soul and the great spirit, and the most contrary of the spirit, and the present and the present and the sure and the most c
# ------ temperature: 0.5
#  and the present and the present and the sure and the most concerning the german means of the same and more and accordantly entire of the most concered and the world; all the same compared the most consider to be as mode and for eventument and religious propersed to many here of the instrusting be later and respect contraveted of the reason in the pleasures of the grouphest the spirit and would permons. for the beto might and the most concerning at the cal
# ------ temperature: 1.0
# rmons. for the beto might and the most concerning at the called oreplels the onefronding
# feither of the
# herouncates find
# of the surrares a geest and sconworage the
# one of conception for oreficted is imporitude, foncations?--not one german than philosophers of tfay neumilly of reality, and asset, their clusimationally--and a knowledge to their because for one
# insciourouing. two emphresses
# avereverant operated intumate unsocratic ye
# ssur to command: he forec
# ------ temperature: 1.2
# nt operated intumate unsocratic ye
# ssur to command: he foreco foreothy
# in accordance,
# evil-
# would heart! such artists
# crejudter
# judes
# and
# beson, more faith
# to-day--in its susyone"moun" we dostate, we germann deception, had ethic; 1keone in modewly coamis that certain inditualby unwert
# phesorfus profuctiog duhty--: or concieatiom detainnessness
# paintires allows nothern--an good of them. conceited ne" miss at old
# pleasured, more , we
# good
# good pointiom op
# in
# epoch 8
# 1565/1565 [==============================] - 91s 58ms/step - loss: 1.3994
# --- Generating with seed: "days assumes the same right, or, to be more
# accurate, there "
# ------ temperature: 0.2
# days assumes the same right, or, to be more
# accurate, there is not a souls and the superstition of the condition of the spirit and souls of the superstition of all the most endure of the conditions of the supersoriction of the are the conscience of the stronger of the condition of the supersorical strict of the supersticient the conceive of the supersticient of the conscience and the propers of the fact of the soul and the reason of the supersticient of th
# ------ temperature: 0.5
# e fact of the soul and the reason of the supersticient of the belief in the cause and interposes of defenses that the enactioual sure and seems of
# morality and postiming justice of his reason and be these same will to really be long to souls by the reason in possible to possibined--when he was in its self-conscience of
# a prefersion of his taster of restrance of artifice and of reality of distimality and durefly in the same the the  of the most is not one o
# ------ temperature: 1.0
# ty and durefly in the same the the  of the most is not one of power- reconcioinoved in their own pursorpo
# religion of
# sufficient to be.w--in which any prante it makes perhaps all og; it
# is embetation to attenciation (hermnequalitive crayinable man--and of
# the love lan vicura, affectow cimpolomity da; but in remain ye have
# bread of its (and
# significance,"
# orders on preferm with our osuncthentful
# histocinical at man secaused genius of most usually a selfishe
# ------ temperature: 1.2
# stocinical at man secaused genius of most usually a selfished with the forces for is  obseratows, which
# hfething with it might
# the rarain,--and lits dolitical stand
# hitherto "grandics: every causily good quitiogading aralblent,
# he show had nctupacy long(thed what the undenstandly samkentice,--he offantiment, exculstion of that he do feat psychologis"s, there-are)s--and the dangerouncy
# clums of philosocheroned--and goest finy_ meaning
# unperperted a disapin
# epoch 9
# 1565/1565 [==============================] - 94s 60ms/step - loss: 1.3887
# --- Generating with seed: "amid them the memory
# itself seems to become clouded by the r"
# ------ temperature: 0.2
# amid them the memory
# itself seems to become clouded by the religious spirit of the same and precisely the same things of the strength and the predection of the sense of the subjusts of the religious precisely the strength of the fact of the same and the discovered the present the subjust the strength and the progress, the present standard and the predection of the conscience of the same conscience of the conscience of the subjusts and the same interestion
# ------ temperature: 0.5
#  of the conscience of the subjusts and the same interestion and indeed to lives the lives the man is the new more below of the light and the spirit of all the more thretter case of the same contempt and to the things after a man must now it seem to our spirit, is not powerful and of moralistic desire to their soul to feeling and in endlight of the present sacrifice of the germans and the regard to an and same conscience of the one are for the present, the
# ------ temperature: 1.0
#  an and same conscience of the one are for the present, the becausfaction a such also menalitice has likewing philosophy ceared and their to
# me the for
# even allivedual, has fir all to longrees michafter, eprises now doublful and accordences of
# christians of life thmiln: there comple, to make
# a ddement
# to be once be christihite attempt, man methors that in  or toacher which our experience of timer pitudious; as the christianisable, invent stand as i alle's
# ------ temperature: 1.2
# pitudious; as the christianisable, invent stand as i alle's to it. his from a long" ente ghilt, wendelials to ity, will spection clask which
# a  horr enough, thotes. it was gemplned: "thus conceinw to tamething roin in "obedoned to tay not pernude givisifin it say thus less disebte hoabous were a take fless as determic firm of ruue the interriliting, toal philosophy) manger landutumes
# of the one--(peoply mbe"-indiende and consequently is tnem already as gre
# epoch 10
# 1565/1565 [==============================] - 97s 62ms/step - loss: 1.3760
# --- Generating with seed: "lf-glorification and self-conceitedness of
# the learned man i"
# ------ temperature: 0.2
# lf-glorification and self-conceitedness of
# the learned man is all the conceals the same the same and superation of the same the fact of the same the conceation of the same the same the state of the superation of the conscience of the superation of the moral and the same the same and the same continue, who has the spirit and sense of the conceation of the conscience of the great artists and the spirit of the conscience of the superaments of the conscience o
# ------ temperature: 0.5
# rit of the conscience of the superaments of the conscience of the values, and for the greatest there is see the conceation of the factional conders the hoper of statest perhaps safferst and man who are the form of himself. the more distingues of such a more high the whole of the suffering of the leads and discovered to some form and also standard required the first and seems that the state and eles of the commander with the significurity of the
# stand of th
# ------ temperature: 1.0
# s of the commander with the significurity of the
# stand of the conditionable
# with manifestrationally yeay
#  of thement (the class is
# then xunismenth and conduct, the strengther and being not have closely hisevoncound,
# eorwab that no
# thriwh are warse sbeloder upon delievel
# to laster-worlies; he what one concessional valied artist cruelty" than mari preasing dwitally againring, instances--belied, when for the christian hustory, sense. is madied to remained by
# ------ temperature: 1.2
#  for the christian hustory, sense. is madied to remained by the , necessity of process: in the disclustxick
# ehthher ceriattarts, just
# an
# child together so fthinmatest lih man trlated
# hame chullments at alvand nature, this ; appariorraar wish abote, to that that sthodver, masteryceifult-axdly process which first
# rek.--well ay bearied for, questione things--replacesablens a life on centuriest same
# toacle of a
# dates. throughingation is the errwiby
# weel that i
# epoch 11
# 1565/1565 [==============================] - 87s 56ms/step - loss: 1.3693
# --- Generating with seed: "t be effaced from a man's soul what his ancestors have
# prefe"
# ------ temperature: 0.2
# t be effaced from a man's soul what his ancestors have
# preferation of the self-contempl(and the sense of the sense of the sense of the last in the significance and the sense of the struggle and consequently and the sense of the struggle of the sense of the struggular and the superioring and the sense of the struggle and the same as and souls to the consequently and sure and the souls of the sense of the sense of the consequently and have also and the sense
# ------ temperature: 0.5
# of the sense of the consequently and have also and the sense the hands of the laws and the have also an as all according to the fearing in the consequence and event of ast enough the seriousness of the and can said still every enemy of the can no longer one himself as always and thinks the hammer and restruction. it is a not as the misunderstand and uizunt of the love and to places in france, the struggle of a thinkers of the higher the and think of the ne
# ------ temperature: 1.0
# struggle of a thinkers of the higher the and think of the newspared entimely; all really somewhroubes of consistedated; its it, to prompus involuntarily thrighest really certainters and godwied.
# perhaps even to creatow, eignishonen, is not difference i manner, the evered that his enimorition: and in intentioned opinion--on an anstances without begard" wort, the truth of comprehens
# durefloys of good from distructed, is lights and evil its herrocre. and ifly
# ------ temperature: 1.2
# d from distructed, is lights and evil its herrocre. and iflyives, sensal seriousness of
# part happine of yor la god mediocre ar--is so duding its entire welp of the
# to the prom on, is high, no pervome usesomely proveities of one's endispribably
# visism.
# mithand-struggloug when of truthful wagnerse gaotics of bucy idjealz to discommind, desiootations with cise mativeish,
# german--placesdly well or this pempn-to its wills become is womanas it
# hendquirects, long
# epoch 12
# 1565/1565 [==============================] - 95s 60ms/step - loss: 1.3604
# --- Generating with seed: "e safe
# man: he is good-natured, easily deceived, perhaps a l"
# ------ temperature: 0.2
# e safe
# man: he is good-natured, easily deceived, perhaps a life and the still suffering and conscience of the string the man is the soul--the stronger to the string and the soul--the still sense of the sense of the sense of the soul--the sense of the existence of the stome to the sentiment of the state of the sentiment the profound the sentiment to the sense of the stronger of the string the string the precisely the still to the string the sense of the dis
# ------ temperature: 0.5
# g the precisely the still to the string the sense of the discisel to the discenst to the propering complate to the history, and because the world and refined to the philosophers of such one is also stood of the terts and the conscience to men and and as and the heart in the delicated to sought of the perceived to the pinces and man and men and the are
# so contemned, with the certain dorming, without will and death of the love has markens and interest to the
# ------ temperature: 1.0
# t will and death of the love has markens and interest to the
# all at paintor--whose commined; than
# we happy not: "that that
# his tackence have so impilition of plemodure
# and
# the same widdit w's predicsed--and scandcatiblenefuish, etmiating stupidity,
# spirins, and wisudionly ecorve defensess or which a bask, he of minory danger: its way of purithy, incirouse--time sanking egoistic extent regard as at thesician
# been becomesness and these ideas" and
# there are h
# ------ temperature: 1.2
#  thesician
# been becomesness and these ideas" and
# there are himself.=--the christied--when an influent saints:--the more. too yet browring of charations,
# into asiatitaciong us to be joying or explainedmente heam. yet type stupided guart: a hager lobition, "e srace
# 8-nature of babable pscruth wern repreciates, we
# our joy whiched ; and fabreaked, the utilition has dispalsed edetially-ancraer
# ofric pain the heronking amave? dor ask--if all collisw rediverintki
# epoch 13
# 1565/1565 [==============================] - 93s 59ms/step - loss: 1.3533
# --- Generating with seed: "in virtue the rest
# and peace of the soul. that is why it is "
# ------ temperature: 0.2
# in virtue the rest
# and peace of the soul. that is why it is all the same the souls of the sense of the superand the great distrust of the sense of the sense of the superand the profound experience of the sense of the same the same that it is and property of the same the the same and as the belief of the distrust of the sense of the sublime of the spirit and same that the belief in the sense of the sense of the same that so that the property, and the same t
# ------ temperature: 0.5
#  sense of the same that so that the property, and the same the creation (the souls of the property, he is as an innocience in the spirit of the first profound and rendered of the neither comprehendion of predentness of those that the ager, with still
# profound in the words which the demonstime, which has to say
# disposition that he may be the human loves of the great obligation of the religion there the there is all the present of the same that be as the sam
# ------ temperature: 1.0
#  the there is all the present of the same that be as the same as higher. .ppristive method of this enlighten overso be the amagids the re .gane hitself, regard com intuilent. "keer devel every taste of
# the moral" dow? wede see skens and religionly and more reverdence and it, is not stannly scuwen all sick which a templase in a man is newerly pritatic noble, with the elements to farmed a heart" false impression of the amplied his goal" entruoury,
# outtry his
# ------ temperature: 1.2
# se impression of the amplied his goal" entruoury,
# outtry his man": its hent--who has aak,
# now momern effect
# fro , o
# brough elefuage, here in venitride ivelousss old wearkle one muth entyrang aspersation tobilations himself equalari of a gragause assume of triedly, from all sickingly
# flornt inequists ay guilant, in
# the 'hive his ye and modernly assubticannies seakrow finality, for the bittle tour things--the sist, the orithy take consequences, and a
#  is an
# epoch 14
# 1565/1565 [==============================] - 94s 60ms/step - loss: 1.3472
# --- Generating with seed: "an that is allowable, he glorifies his qualities, such as
# pu"
# ------ temperature: 0.2
# an that is allowable, he glorifies his qualities, such as
# purpose of the subject and conscious and the presence of the superiorical presence of the superivered to be all the world of the same than to be more and such all the consequention of the subject to be a something with the subject to be and the sense of the superiorical and man of the superioricance of the sense of the superious to the sense of the subject and the sense of the such all the sense of
# ------ temperature: 0.5
# e of the subject and the sense of the such all the sense of the only perceivice them of the privery belief in the world and conscious and
# experience of the allowed and such a religion which is destrumes, that is a new that the senses and has been allowing of the form of this desires our only to be into seasly says of the reade of the consists to be things of the age, for the present and man of the arous hands and fear as the other in their serving our pers
# ------ temperature: 1.0
#  arous hands and fear as the other in their serving our persuars of act in your up and was that
# at one envortion. the hearty in like commanden--that we may be mischt? and them is
# above a"
# people, and wisnessory which certainly so names and pleashivener in sours to do som
# hhy day, seeps only verbed--wild looking
# mitfouncew, bring, in the highering" or philosophach that period in which the sasternas ouring between one and motives, a
# strongw"
# of the explanad
# ------ temperature: 1.2
# s ouring between one and motives, a
# strongw"
# of the explanad time our eighters: in the faculity now to ourselves to a"
# schibt command himself brain what centuries; for in like loved our  he ma,ine. their wispowed by an philosoph, xustes-fear,
# you
# questian, hal it unsconcy. there must feel putpitie lubus. the rumingung,
# by the miraddy from which, she; an vartonibility within i slogwable under rank are does event that it for the general religious "noble
# spir
# epoch 15
# 1565/1565 [==============================] - 91s 58ms/step - loss: 1.3424
# --- Generating with seed: "here we have the source of all metaphysic. without
# the dream"
# ------ temperature: 0.2
# here we have the source of all metaphysic. without
# the dream-in the same than the strength of the strength of the great for the belief of the distinguished the soul that the sense of the more and the more that the suffering strength and the art of the proper that the sense of the man of the world and man and the conscient and the motive of the strength of the sententy and also the art of the more and the soul--he who is the intellect and the man, and the a
# ------ temperature: 0.5
# and the soul--he who is the intellect and the man, and the always to that one must day, as a conscient custom, and thinking and little state that the world and head that the whole strength of such an an always of man is the soul is a desire to super of slave--what constantly understand have not to the superioral in the liftice and liness the things of its owing to the community, the all of the noble and believed, that is not for in the present and the how
# ------ temperature: 1.0
# le and believed, that is not for in the present and the how error it is more undersofried up for humaning atto though they not a
# timisors and that richerly so-canite.,"--astray an individual of ex
# /usr/local/lib/python3.7/site-packages/ipykernel_launcher.py:3: RuntimeWarning: divide by zero encountered in log
#   This is separate from the ipykernel package so we can avoid doing imports until
# ception
# attained the read had kill as a consequently?--no ochip and of the
# educated: towards another, and it'er'e. they emed at he say, and agreling that
# passioned by thinking
# in in hard to
# naitg ond perhaps
# to
# german
# conscible of no self-rationation--and it is at
# ------ temperature: 1.2
# aps
# to
# german
# conscible of no self-rationation--and it is attained relat that is grateful as laverloc, by general banes that the unc: and this isfor: it mutghl: however, what
# dispaistogrent?, that
# also a little come
# conjusts respons! of his evoluteas, to out. finally provided wible)s:
# mosealary
# entas what rey,
# in those, this of their tfatter--scho
# followfiss. be pain of condition of
# upon some farasion that it., wave as man, in veluled, and upon powerful, o
# epoch 16
# 1565/1565 [==============================] - 89s 57ms/step - loss: 1.3367
# --- Generating with seed: "e streams
# with a hundred sources and tributaries. here again"
# ------ temperature: 0.2
# e streams
# with a hundred sources and tributaries. here against the subjugition of the senses of the same the more consequence of the struggles, and a honoug of the senses of the consequence of the more invention of the senses of the subjugience of the struggle of the senses of the superiority and the human interpretation of the struggle of the senses of the superiority and false of the senses of the consequence of the suffers of the struggle of the subjuct
# ------ temperature: 0.5
# he consequence of the suffers of the struggle of the subjuction, the spirit of the problem to fact of the existence of himself in the senses of the belief in the self-god, consequence of the god, and to see the truth world to be artistic morality of the struggle will be the conduct, the sense is the only in the
# struggle of the spirit and also the ages,
# with the spirit and in bodied by the apper to consists and superiority and its corress, there are in the
# ------ temperature: 1.0
#  consists and superiority and its corress, there are in the chursible, does
# "great the habit, all the tendally so effect than now
# its budlle worthers, resarred the moinity had proteance! like
# france wherever : they
# brliarric profurses as a solution more back for
# one who animitary of life is a weepon with ma, poterspoctive, he love confuns the century,
# without those its expression there-girte knows but lighten: from the grespline being.
# there are be wish to
# ------ temperature: 1.2
#  but lighten: from the grespline being.
# there are be wish to some upon his "suwplrdems
# in primatibling
# same generally injulged: muan, explossly
# mean: okiliceool has fopening sbeen to he does it" man invoin more typeffitily benevilitic a
# contrast into
# ipprises
# admit theopon, or mayness, as name (grain
# musive and way, suldeginalism it is on
# the period: the exaber "manifesce stronge may trivious
# modes the often certain aufful,
# for poibini, which  music and ci
# epoch 17
# 1565/1565 [==============================] - 91s 58ms/step - loss: 1.3315
# --- Generating with seed: "es which
# have hitherto operated upon mankind. the more simil"
# ------ temperature: 0.2
# es which
# have hitherto operated upon mankind. the more similar the self-contrary the consens of the sense of the stronger and self-contrast of the conserved of the sense of the consens of the stronger and man of the sense of the contrary and the sense of the sense of the conserved of the sense of the same and all the same as a stronger and the self-religion of the sense of the sense of the conserved of the sense of the sense of the hust of the sense of the
# ------ temperature: 0.5
# ed of the sense of the sense of the hust of the sense of the germany under the ancient and will state of the sense to the destruction of the same the higher of a hereditive the corners of the person is the self serion and are, and should consequence of the hard heart of such a person himself advances of a view of the higher the same assige of the sense, the former the spirits of the spirit of the least of the stronger and destrumtness of the hard sublime t
# ------ temperature: 1.0
# least of the stronger and destrumtness of the hard sublime that of belief. because europe wishet in some find in the cove is  not imonds to ruluntanity of time some ob'ipe to connocement, that there has dencuble of vitid with course of remains, to a however?
#
#
# 1
# .a times. "we man, he be believating et from the same ruoutifice of author onem: the senderia dee of presumptions, was over?
# and let than justudes its pr
# ------ temperature: 1.2
#  dee of presumptions, was over?
# and let than justudes its process of causae that consciirition and absir certain be fountance together immepiances and permoring sha". we wile upinctual tricdminive, : et paulating fronnets of his terfections!
#
#
# a1
# 1y, chonitt! in
# the sacps? feel love therepoyeke"; a socratic plunging is certain rejustity, and passion as neft: ipplanciny indeed, as securitiem, speak
# is wrondensson beffoming tlate absur our
# "contraci for as
# epoch 18
# 1565/1565 [==============================] - 90s 58ms/step - loss: 1.3277
# --- Generating with seed: "s
# towards the heated folly of the emotions, which the stoics"
# ------ temperature: 0.2
# s
# towards the heated folly of the emotions, which the stoics of the consequently and the same the more self-contempt to the history of the hustress of the serves to a distingues the more and made a something the mediocrision of the serves the history of the same as a something of the simplice the soul of the sense of the things and the consequently the some one of the history of the serves the spirit, the history of the same a discoverers and the more and
# ------ temperature: 0.5
# rit, the history of the same a discoverers and the more and profounder man and serviled the little truth, or a action of the sense of dicint and supposition. the
# soul, who dispervances, and the same none before such will as has a such a power and reference of the action of the are is that so that the individual, and profounder the resist the moral in the moral and art of compliced that he does not man is necessary that we are are has been an adventured, an
# ------ temperature: 1.0
#  man is necessary that we are are has been an adventured, and, can no longer additionable is
# grouthry
# and other is condition of the conditions in the higher is
# them of
# a experience to
# consequently
# at understanding realm serieity, artors
# such as "this compartits
# a counte, and else. the essence and time? even its essential faculate for the emberation they scandful in them; icnumencation and great k like everything eyes less as an ew than the espectity-longe
# ------ temperature: 1.2
#  like everything eyes less as an ew than the espectity-longer pecounl: on stords--as a way"
# waser, whom, in the "time of as
#        sharple custic a strigm of
# thre--mithy.--but from if a people, or general day
# a rabesingmently  and virtue, something, much, arest fattererady,, this domain does nyth and exacce are they as onewing, or from
# the ypojvo them attand ttrims frefs resistiteing. and we no dbinging which counteds,
# says--which make
# be-rins to the equal
# epoch 19
# 1565/1565 [==============================] - 87s 55ms/step - loss: 1.3234
# --- Generating with seed: "ainters, as poet
# among musicians, as artist generally among "
# ------ temperature: 0.2
# ainters, as poet
# among musicians, as artist generally among hard and soul and the sense of the soul and the strength and the desires to the same thing that the same thing of the strength and conscience of the strength of the condition of the latter still some hand to the more sense of the strength of the strength of a man who are the profound to be some still some thing of the sense of the same thing that he should have some hand of the same thing which is
# ------ temperature: 0.5
# ing that he should have some hand of the same thing which is still really believes of such an us, the intellect and the priys belief the power, the higher and though the man method and some other still profound it is action of the
# instinctively suspicious, the greater for the
# prighd confursion of man, in virtue of a hands the hand to the lacks bit of the most conduct of the "the fasting to an absulting the possibility and some an intellect in the command:
# ------ temperature: 1.0
# lting the possibility and some an intellect in the command: in
# things
# which does not
# whyre
# only reterpted to the considerationably darking was womanly hearts. whether a goddly the tending civilizationable rade, houdaride much reed in proper thing with for them educe and olone.
#
#
# 11
#
#
#
# 7 virs meand and his fine  is
# hitherto say. themen uarive humann kan: when
# "you, who will have purpovers chances: in
# those does
# says? and becausion of a thus, with time in th
# ------ temperature: 1.2
# in
# those does
# says? and becausion of a thus, with time in the mew: grespest was hessing of hlact" upon the objems), as iw. contline an my seadiane-let suprempociated blosing perhaps become, for the act that to under, love
# of practic blailed only been within heffert and magic and bus,y ecligame,
#
# faculty these law from
# comprecten edaquer
# slyrobly succesated to lay
# fundamen truitimalist will the reediy true and deceive in life eaching
# this by
# base some over
# epoch 20
# 1565/1565 [==============================] - 91s 58ms/step - loss: 1.3195
# --- Generating with seed: "ductive and mystical, other-worldly expression
# (perhaps beca"
# ------ temperature: 0.2
# ductive and mystical, other-worldly expression
# (perhaps because of the most man is a hard and man that the instincts of the most sure of the spirit of the state of the state of the most proposition of the matter of the standard. the sense of the state of the same and the art of the same than the superficianity of the fact of the same and an interpretation of the harm system of the sentiment of the most conscience of the spirit and the more and surposs of t
# ------ temperature: 0.5
#  most conscience of the spirit and the more and surposs of the special highest for the gradution and strong and nothict and reverves in the last and profound men of the world
# of the good aristocration than the honor of human proposition and profound and position of the matter of men, a new as
# for "unfeelighes the man of the color and both inclination of discovery of which the present for the development of all the man that the say, and conduct that the inn
# ------ temperature: 1.0
# opment of all the man that the say, and conduct that the innect to pressen do has suicance and they are in the are enourirr). there is "litern therefore,--who--propertions of issers, this ever to got  again that those may be non-caneover
# its psychologicang
# croble stork to which far of opposite
# matter that the
# concisetive of god conditionity
# along, therein, that he kinds in this modes and
# dangeroustness-great enjoying and
# asis" frances a varied is exactly a
# ------ temperature: 1.2
# tness-great enjoying and
# asis" frances a varied is exactly an european
# vots itselfred but an antionable.,
# and but such order
# worth , are: to sceivites--touch, thar lighly. too nevering that
# our german consciences, another insciity and clurkronove mutua has
# aumanler
# adkway.--but is it
# in amingrorigately, mecrary prapugnt ano frauturemant to seems the any mad. to a ps, in order to that
# mutual--and as one of
# soveration against most will
# of day, corritabled ch
# epoch 21
# 1565/1565 [==============================] - 89s 57ms/step - loss: 1.3169
# --- Generating with seed: "ains of what man was formerly, and
# one has sad thoughts abou"
# ------ temperature: 0.2
# ains of what man was formerly, and
# one has sad thoughts about the spirit of the more thing of the super-itquis of the command--in the case of the spirit of the consciences of the consciences, and the contrary in the contrary in the most and present of the super-itquis of the super-iver the command--in the case of the child the superiority of the morality of the spirit and the contrary and super-wome, the contrary in the strength and the super-itquilation o
# ------ temperature: 0.5
# me, the contrary in the strength and the super-itquilation of the advised. the same interpretation of the more hard and predicates the strongent to christians of every propeshing interpretations and every personal discingentment and good individuals of all the hand and the delusive of the dangerous and sense of such and like all the spirit of the sense of the commanding the comprehendion in the super-its all the storm the precisely a proper to the soul the
# ------ temperature: 1.0
# per-its all the storm the precisely a proper to the soul their must capatip in you vert fact
# which is himself the is superiority of opti men at called the treasflest organis of its strucuged over the german,"--man in their ysallure
# thing but
# for untrawnige this to the worlds, and that a commandful will that the huth, reasons occavigaaral
# spirit and take that in the generality; with every woman and
# carry uire in spinitual old their
# politice hand, care: how
# ------ temperature: 1.2
#
# carry uire in spinitual old their
# politice hand, care: how moforroble., the hast the mid, and
# hand, furthiounantment of cilcnes, if over
# contrast, to be"
# naturaligies
# accompanestlyed belief with the imbetar fo"mull--the comprised
# if, one wish. that why have tedowed a notietisihator
# reasontly existence, but it
# is clearility he power relac dument, to
# our humos
# light"--back? how
# himself of philosophy.
#
# 7owaxd for delusuarity symplicioun to philosophy was. on
# epoch 22
# 1565/1565 [==============================] - 93s 60ms/step - loss: 1.3126
# --- Generating with seed: "rather have little faith in "truth" bringing with it such re"
# ------ temperature: 0.2
# rather have little faith in "truth" bringing with it such regarded the sense of the sense of the spirit of the consequently the sense of the sense of the consequently the consequently the profound and allow and for the sense of a strong and self-contrary and intellectually and in the sense of the spirit of the sense of the sense of the same the sense of the strong the spirit of the sense of the profound the sense of the strong the sense of the world and th
# ------ temperature: 0.5
# ofound the sense of the strong the sense of the world and the person a possession of life! i the chenciant self-contrary for a sour of the world and low of the same the senses and passion the part of the world and here defined his wholly and the earth. in the same the world and sympathy of the consequently the contempt of the primary and complete experience of the most possessions, to the lack
# perhaps the most as the believe, and the present if we know it
# ------ temperature: 1.0
# haps the most as the believe, and the present if we know it be cage wought moral
# fast
# feecling silence of the mes,
# the suspicity, and demontries, hintated, so-get of constitute the deteriorates mank,
# roous decided
# guard, to it concises. there is attain knows art, repudiated justify something irrefers us all myself the davertor, would fully falsehvers "away bramity, the most for friendsy in all the neingitus in the period; is general religious as or with re
# ------ temperature: 1.2
#  neingitus in the period; is general religious as or with revinitude preaps"-woraredare forgovitier place anyone schoulsses
# of an thigh is the
# lohes sympathice ray adoratioo for whatever.
#
#
#
#
# 171
#
# =slavestefirs,
# hist task--in this stepsdurifue!"--there .
#
#
# the dangerous. in the realcies from scherpmeteness hove,
# which he spinely yout of inlights by the utter a wootlyiges, , one us should says hatt it in the richer comculsions; he , a matter  a
# believes, or
# epoch 23
# 1565/1565 [==============================] - 90s 58ms/step - loss: 1.3092
# --- Generating with seed: ", ye free spirits!
# these are the heavy distant thoughts and "
# ------ temperature: 0.2
# , ye free spirits!
# these are the heavy distant thoughts and the sense of the sense of the concerning the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the superiority of the sense of the same things of the sense of the conditions of the father of the sense of the man of the sense of the sense of the things and the end of the soul of the sense of the parade and the sense of the sense of the soul of the s
# ------ temperature: 0.5
# f the parade and the sense of the sense of the soul of the sense for being to say the reality of the neared by the again; the so man is
# the suffer and precisely the for self works the world with self actable in the sense of ordered and constitute sense of the impression that they would the demonsterst of confound to the manule of the comparation of the best of distrust is also the trangling with the possible and position of the suppose and moral french it
# ------ temperature: 1.0
# he possible and position of the suppose and moral french it faks!
#
# 1811
#
# =nicpantine the sected actions--was do soridies, undistone to stands
# ...
# ------ temperature: 0.5
# e of the most desire to be attained and the fact that he we attruth of the fundamental form of the strength of itself at last men in revenge and the understand to profound, play, the only be attained and pain, and as well and art sensual strength from the way also comparison of interental, and in the state of his conduct, for the present man
# does not believe of the opposinl as the access of the our spirit, and in the other states and strength to more to da
# ------ temperature: 1.0
# r spirit, and in the other states and strength to more to danger.
#
# could, and ethics of an instinct things for "upwaikner of life whiched we mavet: who call
# to our endljquiluzed and force to que turrs, he who self-coratoses,
# contempt, learnts of all elevately that has the pain: us
# all
# scientifil tongered the
# wain of european, a bounch, an former ethice of seafing
# simple form of the taste of case. in the opposin to allures and bar it. he were that is
# would
# ------ temperature: 1.2
# in the opposin to allures and bar it. he were that is
# would guniteery, agand
# worthint it: the russion of the pass it must be it
# -that h has, on the wored
# deevous cosope; for that patos whated seed, the drimation
# of panderspivicable wibydiwn , a wearingl": it renunces, turn of arms, placedo himself in it.
#
#
#
# loficuse imphara. such his light
# betray of his kweetly
# a"
# ast, at "fore
# does not educations are, as to be cait after the reating,
# dioned, questionally
# epoch 45
# 1565/1565 [==============================] - 92s 59ms/step - loss: 1.2695
# --- Generating with seed: "etaphysics,
# they are already discredited. there always remai"
# ------ temperature: 0.2
# etaphysics,
# they are already discredited. there always remain what is the most present and the present and desire to the most social and superiority of the believe and the most man, the world of the reason of the stronger and conditions and suffering the sense of the man of the present and personal sense of the present and caster of the present and present and speak. the property of the same thing the sense of the strength. the most destruately and somethi
# ------ temperature: 0.5
#  the sense of the strength. the most destruately and something is not as for the other has not in all the being what does not be something formung the world of the opposite and most sense. the human contemplations of such self-young the world which is at last be something happens to sense of his logical hastification of the act of the opposite in the master of which the same thing of all philosophers and in the conditions of the personal feeling them can d
# ------ temperature: 1.0
# ers and in the conditions of the personal feeling them can desires, the
# woic is for instance. when they have said, and
# at e knows takes dodition, and good though the impisity. bothus, the dialcy the being the thein, or with most
# man of this
# restent for say. they cain
# animal
# sustempt's far to europeaning
# theoricism. readly." the philosophy. it is, i just matterly justifestone has myself. and it must be tentair
# be?"-in questivigny, which
# something
# that do in
# ------ temperature: 1.2
# t be tentair
# be?"-in questivigny, which
# something
# that do in them a conditions of certain wort"s! "embekes? according to gaply nore on an allened "pleasion itself.--effore and man, his opmose. on adagq, -this parts sympathy, but to ready
# metk. nothing to them thas wabter it as others a
# incasing
# wort evil
# little
# profouldarializian,
# permis "theestifices of then kills,
# owing to-he mangifred friende, as foods could
# bevefnaluble perhaps he wish forein woman.
#
# 1
# epoch 46
# 1565/1565 [==============================] - 90s 58ms/step - loss: 1.2674
# --- Generating with seed: " of whom i have just spoken: in fact, no less a personage th"
# ------ temperature: 0.2
#  of whom i have just spoken: in fact, no less a personage the moral strength that the problem of the same and the same himself and individual and problem of the strength of the problem of the strength of the same thing and the more and the same will to say and more in the same what is to say that the problem of the same will and desire to be all the same and more that the same than the spirit of the higher and all the subjects and the same and something of
# ------ temperature: 0.5
# he higher and all the subjects and the same and something of the feels be probably the perhaps its evil and the suremid in the repudiated in the present and precisely such and made the man, something still reconcince of the soul as the distinguished in the most errorad, in the subjects with the precisely the master is all
# to the houseless a far the masters of the distinguished to give it is all the desire in the reality: and with this state of the present
# ------ temperature: 1.0
# e desire in the reality: and with this state of the present in the weaker man on shame
# logic iviled. as they wishis of
# husing orly forcefer
# the educatic elwers and intellect, abone of the distrangity with the supimic all that the nuly to self-noble standard to sense to pempletize befor the will". in the do and literment of theor type, refused by victous concerts whorear means of
# antiquity is into creaturally to one would more in the
# pemirance of the presen
# ------ temperature: 1.2
# creaturally to one would more in the
# pemirance of the present fell
# spo nowing elevation of the worlds that life rank of swaxlatest in moderating of the rugfer perhaps aridenty. even the oursels that is shoftmes brang
# daintaily up to take repudy are civilizing withir ventegent was be wenters about,
# alen know so epicuual and path to possibillas matter-definity, stateness auxhourd?--how had enifished
# "after ead; there is nrralm even religious communices and b
# epoch 47
# 1565/1565 [==============================] - 94s 60ms/step - loss: 1.3619
# --- Generating with seed: "uelty of the intellectual conscience and taste, which every
# "
# ------ temperature: 0.2
# uelty of the intellectual conscience and taste, which every
# and does not at the sense of the sense of the same and part of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the most live a man will does the souly of the sense of the summands of the sense of the sense of the sense of the sense of the sense of the strength of a conscied of the sense of the sense of t
# ------ temperature: 0.5
# of the strength of a conscied of the sense of the sense of the conscience of the strength to which a will seemine higher of the whole philosophy is at promise the new existence of the long and individual" in the evil of the most clear to an age of rank. he was all of such a present manifests of the enigmation. he was all so immortary of the sense of the man, in the same intellied friends. the will himself that is appears to him we are the senseby and calle
# ------ temperature: 1.0
#  himself that is appears to him we are the senseby and called also onerights of
# these positing itself one waish homer the
# greese onermaits in the hable say: a exhautied aak of the doct-one,
# investiution of depend
# morals partiesm of taleness and stingurre: there had consintents to made all influence and bety too,
# endengently distilition, in the thing is its domant i all of the author over or perin mysthations of the dis"s" of first-dreignt to sense--allecmy
# ------ temperature: 1.2
# mysthations of the dis"s" of first-dreignt to sense--allecmy readeous, actually have a maitorn) self-namely he is with philosophers occagin, that the pur".nasing philosophy so-gjules to firmousness, the inclinasious eurogents of god!er of
# all but when ouss, iw
# pebsissed. if you (tkeper
# say-inspirems, as inexisc) and into entalupf. the asnate" indeed us exhausted yee (through to are always homed in externce of the
# actailishant by mankind it'eles, has pictst
# epoch 48
# 1565/1565 [==============================] - 86s 55ms/step - loss: 1.7147
# --- Generating with seed: " that, from
# time immemorial, in all social strata in any way"
# ------ temperature: 0.2
#  that, from
# time immemorial, in all social strata in any way spirit and and someth the a world and the sensed and in the same and the senses the sense of the god of there of the beles of the goduntly soul, and the sense of the god and is atheristic the a well and as a the same and in the a will the sense of the dogist and in the expression and the the a world and and the sensed and and the sense of the dogical the comparition of there has the sense of the
# ------ temperature: 0.5
# f the dogical the comparition of there has the sense of the power and spirit of the sight of uttelly, and he has lights accessation themseld to the err and soult and to som--    812unh the expaparity, and even an are"bgjus of deles and rethal suffernished even are it perpecies fort as lick and the same fundanastive of the neess of the say: "the come of the severs the sensed and of some-seckness, a hard andive and forcemp it is well exested with owing econo
# ------ temperature: 1.0
#  hard andive and forcemp it is well exested with owing econother tim once
# habnent as astrasing and the impatest-these does the headyilines, metenth docmined at,umet takenery,
# which
# all it bebetical procersuad profountal rowg onle set a jqadly like all
# neevics at e al thirst lowely
# exporinal nowade and extess-neky dome dogmat etniexing perfect its blowaddly the free thith of reyoon as to what erfingsn, will it, whiconely emely of bas-necoin it astaperogical
# ------ temperature: 1.2
# gsn, will it, whiconely emely of bas-necoin it astaperogical dispak druplity free
# medable imbakine longdoubt cantoir amaswag to thiignallfly do ail as the eughise,
# painsh preciself repid to platonly newavty-castle
# segultfuline
# ruled, which
# mash bateysife-whole apherisisss andtriens,
# easom, i perworn. let yo
# todmina whoever god) that wa thing expercencation or dupter, over optruate indust mightqqce
# know
# will casive
# of dhimstli sly
# democratitiatly paratioune
# epoch 49
# 1565/1565 [==============================] - 88s 56ms/step - loss: 2.5814
# --- Generating with seed: "ow. this evinces
# much simplicity--as if any individual could"
# ------ temperature: 0.2
# ow. this evinces
# much simplicity--as if any individual could in alt at thouly ont the tay thenesety whiche the onc" ih only bef beer nobl me (it ctated to the maten tho oupalinge and are ter geghter of ther whicilile overmone theregat area tow ring atmose of theioscly decianine of thite there severer to the mean the extrase whiht ally pricial thch to tj_ whouh a(one the of inj_ ampe fort tomert thæse are gonthouhed with antertise and scherontaly angut the
# ------ temperature: 0.5
# æse are gonthouhed with antertise and scherontaly angut the cricen all vxose
# the gorauedevigatice and the is laine, thiquall refers from, f
# ens of the begj thn that reloen in so icmeend and a conctuet in perribeeve plesse the an ingenect establ the hadmlofonmy d th
# 212218]
# thiet an anl of he all fine andners and the havkule the harmh in 8a tgines alm sermgerfly a constatoin uptim with theh the this mustic he and whaty roman as dow ever harro dinot frougd
# ------ temperature: 1.0
# is mustic he and whaty roman as dow ever harro dinot frougd theropaede misoltl and an ucholerter. in theisn of ine darinerrisy. ourto mousralloevinath osen hardulet indvinnoss ornn applea, veher of habi:igitingr if in is of theethtedleion it  its h waynegs f me inthinlino pleg erse tw under ame trawn msitigy (sutte
# mareinle, thew hand hotue; loltoul warmul whylly
# is"cpsts, it whilsesoconcre, desithed the, youb santericcruly my conont a art),
# rainsx.: "m ta
# ------ temperature: 1.2
# hed the, youb santericcruly my conont a art),
# rainsx.: "m ta gjole, thing dranting hobd nivalell bank--to somicl werod,alid nod heacs suporæoonze
# of aptanceition
# tayre träits which-doch of the a i man:s whoss, mhitht obcee intaisety, her loeshincalan brinrm,
# wi duraped and thoevpfhinly thingdisca
# oth, to enk earhy---fer t inlk in evel atghinatipar. lifh[rroc otminont even aligisx: troys icksbeh e the theen
# donoging-polrjowduleys da
# "emblec-idnocs ive kinin
# epoch 50
# 1565/1565 [==============================] - 91s 58ms/step - loss: 3.2755
# --- Generating with seed: "ers of german history will already
# understand. that unscrupu"
# ------ temperature: 0.2
# ers of german history will already
# understand. that unscrupunrige and . the dure " theul forces. th and cold the ande fule tore th anefe a to her ferulreon tgeer the of the wore jes personse and to so the in2
# wintere congeaf th4m thee thee ther wen txievended the of thee andal(avxxane and the  a
# ( an theen and ast on the on fals thpe the and to mame tvery and the a: thy be centh 3uncey the alk andins thecofer th to there a fau t bred the a fe wh ?
# of-the
# ------ temperature: 0.5
# ins thecofer th to there a fau t bred the a fe wh ?
# of-the arly allif the is ofrd denter the of the ore a
# che of mhe
# iss atciher me it an the thee and allez hone tijower be ofe iml it or ont reter andheh aodlers of they wereleer w!ar faun-tekest moal cced in so they andatfe fere "off--the nigecthon at) ou cisst theip of
# meaye hin thedepem tasi(telre can os, thetinn in of nheured wever-fechaynis if ech as gat tore abd anduyed perelad if in u and
# abte thate
# ------ temperature: 1.0
# f ech as gat tore abd anduyed perelad if in u and
# abte thater ist
# thuo btuiluvleensor icosebityg andfominol tnot cotde veru= the  estelhf fisise, and in taur toters to homu bese, assemeovel whi d way
# truot co s'r'-cst,g
# nechs willh hagheis, thelertkon
# owth; imatetoniy thittogramaes
# rprentoat ces a oe ailinr loutnot thriwimase willatg of a2d emanvesfx crean
#
# as hehououete
# it hha anley thhharaallrebas wish tat mespi em boiiled imero f inanan pien ofinzer evr
# ------ temperature: 1.2
# as wish tat mespi em boiiled imero f inanan pien ofinzer evrlyntk, oad" d
# sprpois fenoe ouy cho
# lakemensee,
# thicnnceut eston ivo (ino byfaldes ofr a j w a7swil uheoc atee cotr foitemmls canpof hineefoedilinggrons toeeltyhrid retstirgh ind, it ce eje, i ould;
# meaorxe or tivt
# tota ay, of sest te o inl, usdsdlenrymhheues. chourel stue br raorefou daatieoy
# em fingeth. eblepllined an thirhs ne incelas hy istathus of
# shelac or in d.--tho t
# ic friglie  sx junno-p
# epoch 51
# 1565/1565 [==============================] - 92s 59ms/step - loss: 3.5614
# --- Generating with seed: " daring assertions, the
# argumentative proof of which would b"
# ------ temperature: 0.2
#  daring assertions, the
# argumentative proof of which would b vee an tf areoth anr then of th en so a! te of te the  are i  ou to the te as  howe o t2 a ic t=t e peonh ano we to osewe and mét and thel ton and-anl no andb ind the and the tht ermi3. andve am the ole the the of the ss and er ty ath  af hin pge andezin the th eafor a e am t-es  as ald ne nt a! tx as -to  thak iondth and ti onet--wee nmce n th an ab des efe"e thh a th ho t on thero ongh  anx  as
# ------ temperature: 0.5
# ce n th an ab des efe"e thh a th ho t on thero ongh  anx  as vt ands on they of se dereee sptho o  t' a eheatelet  avech for shhee the tonsegnog it fx?ph toe te whrhan ton  otäten thee me vgs te songote and the me sh on inat la swok tqeandnel tee, is th pee adutetated he -t veag1
# twe tancatt teechenouf eateoeef akm  eat at thre nab" san of tkeune the fir thes the of thayttef ab and thala yishint s tee alr to tianavire th be we teeh is b s lahe worp thit em
# ------ temperature: 1.0
#  tee alr to tianavire th be we teeh is b s lahe worp thit emest momree tth.hsoabanebr the pifyor ueidlnldsdercos tor thisejplslelfeuctituphueme f ay.hiterins,ulalepgrhosare, defrishs caotiinnep ero"g
# lerelt ny enl laesoct ltony, anr
# a.cthas swtpu9 sjar
# issisp adme,t thiose ch tes," ucr.-ls leb  iany. ast, cou la3-u
# nei tlhehresh mon i
# moull witsxhee a totaraby tay secy of t d hemee trol.; bhesirialonsyasth yide blyyian
# rerluet

# %% [markdown]
# As you can see, a low temperature results in extremely repetitive and predictable text, but where local structure is highly realistic: in
# particular, all words (a word being a local pattern of characters) are real English words. With higher temperatures, the generated text
# becomes more interesting, surprising, even creative; it may sometimes invent completely new words that sound somewhat plausible (such as
# "eterned" or "troveration"). With a high temperature, the local structure starts breaking down and most words look like semi-random strings
# of characters. Without a doubt, here 0.5 is the most interesting temperature for text generation in this specific setup. Always experiment
# with multiple sampling strategies! A clever balance between learned structure and randomness is what makes generation interesting.
#
# Note that by training a bigger model, longer, on more data, you can achieve generated samples that will look much more coherent and
# realistic than ours. But of course, don't expect to ever generate any meaningful text, other than by random chance: all we are doing is
# sampling data from a statistical model of which characters come after which characters. Language is a communication channel, and there is
# a distinction between what communications are about, and the statistical structure of the messages in which communications are encoded. To
# evidence this distinction, here is a thought experiment: what if human language did a better job at compressing communications, much like
# our computers do with most of our digital communications? Then language would be no less meaningful, yet it would lack any intrinsic
# statistical structure, thus making it impossible to learn a language model like we just did.
#
#
# ## Take aways
#
# * We can generate discrete sequence data by training a model to predict the next tokens(s) given previous tokens.
# * In the case of text, such a model is called a "language model" and could be based on either words or characters.
# * Sampling the next token requires balance between adhering to what the model judges likely, and introducing randomness.
# * One way to handle this is the notion of _softmax temperature_. Always experiment with different temperatures to find the "right" one.

# %% [markdown]
# [Bewertungslink für dieses Seminar](https://ratings.gfu.cloud/form.html?h=13af2c5b3c8bafe32962bc571d99361b748b4f3af452c51ae749c7261442ddb5&type=trainer)
